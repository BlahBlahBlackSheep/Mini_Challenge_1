# %% [markdown]
# # Help ! Find my Baby!

# %%
from PIL import Image

image_file = "/home/xilinx/jupyter_notebooks/common/data/minichallenge_1.jpg"
img = Image.open(image_file)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x30CBE290>
